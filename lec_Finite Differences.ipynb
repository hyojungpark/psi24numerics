# %% [markdown]
# # Solving Hyperbolic PDEs via Finite Differences

# %% [markdown]
# We want to solve
# $$\partial_t^2\phi = \partial_x^2\phi+\partial_y^2\phi$$
# $$\phi|_{\partial\Omega}=0,$$
# where $\phi = \phi(t, x, y)$ with $(t, x, y)\in\Omega$.
#
# How to solve this easily?
# Define $\psi:=\partial_t\phi$. Then
# $$\partial_t\phi = \psi$$
# $$\partial_t\psi = \partial_x^2\phi+\partial_y^2\phi.$$

# %%
using CairoMakie
import Pkg; Pkg.add("DifferentialEquations")
using DifferentialEquations
using LinearAlgebra
# Out:
#     Updating registry at `C:\Users\hpark1\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed Sundials_jll ───────────────────── v5.2.2+0
#    Installed TimerOutputs ───────────────────── v0.5.23
#    Installed MaybeInplace ───────────────────── v0.1.1
#    Installed StaticArrays ───────────────────── v1.9.2
#    Installed Polyester ──────────────────────── v0.7.9
#    Installed RecursiveArrayTools ────────────── v3.8.0
#    Installed DifferentialEquations ──────────── v7.12.0
#    Installed NonlinearSolve ─────────────────── v3.5.3
#    Installed FunctionWrappers ───────────────── v1.1.3
#    Installed TriangularSolve ────────────────── v0.1.20
#    Installed RandomNumbers ──────────────────── v1.5.3
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed Distances ──────────────────────── v0.10.11
#    Installed Static ─────────────────────────── v0.8.9
#    Installed SteadyStateDiffEq ──────────────── v2.0.1
#    Installed BoundaryValueDiffEq ────────────── v5.6.0
#    Installed Tricks ─────────────────────────── v0.1.8
#    Installed MuladdMacro ────────────────────── v0.2.4
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed Functors ───────────────────────── v0.4.5
#    Installed SimpleUnPack ───────────────────── v1.1.0
#    Installed ArnoldiMethod ──────────────────── v0.2.0
#    Installed DiffEqBase ─────────────────────── v6.146.0
#    Installed BandedMatrices ─────────────────── v1.5.0
#    Installed SciMLBase ──────────────────────── v2.23.1
#    Installed ADTypes ────────────────────────── v0.2.6
#    Installed NLsolve ────────────────────────── v4.5.1
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed LinearSolve ────────────────────── v2.22.1
#    Installed SimpleNonlinearSolve ───────────── v1.3.2
#    Installed DiffEqNoiseProcess ─────────────── v5.20.0
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed TranscodingStreams ─────────────── v0.10.3
#    Installed Random123 ──────────────────────── v1.6.2
#    Installed LevyArea ───────────────────────── v1.0.0
#    Installed JumpProcesses ──────────────────── v9.10.1
#    Installed OrdinaryDiffEq ─────────────────── v6.70.1
#    Installed FastAlmostBandedMatrices ───────── v0.1.0
#    Installed Lazy ───────────────────────────── v0.15.1
#    Installed CodecZlib ──────────────────────── v0.7.4
#    Installed StaticArrayInterface ───────────── v1.5.0
#    Installed Graphs ─────────────────────────── v1.9.0
#    Installed MatrixFactorizations ───────────── v2.1.0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed ArrayLayouts ───────────────────── v1.6.0
#    Installed ImageCore ──────────────────────── v0.10.2
#    Installed StochasticDiffEq ───────────────── v6.64.0
#    Installed ExprTools ──────────────────────── v0.1.10
#    Installed LazyArrays ─────────────────────── v1.8.3
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed Sundials ───────────────────────── v4.23.2
#    Installed DiffEqCallbacks ────────────────── v2.36.1
#    Installed SciMLOperators ─────────────────── v0.3.7
#    Installed DelayDiffEq ────────────────────── v5.46.0
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed EnzymeCore ─────────────────────── v0.6.5
#    Installed FastClosures ───────────────────── v0.3.2
#    Installed ExactPredicates ────────────────── v2.2.8
#    Installed FunctionWrappersWrappers ───────── v0.1.3
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed GenericSchur ───────────────────── v0.5.3
#    Installed ChainRulesCore ─────────────────── v1.20.1
#    Installed FastLapackInterface ────────────── v2.0.1
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed PreallocationTools ─────────────── v0.4.17
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed KLU ────────────────────────────── v0.4.1
#    Installed CommonSolve ────────────────────── v0.2.4
#    Installed IntervalArithmetic ─────────────── v0.22.7
#    Installed OpenSSL_jll ────────────────────── v3.0.13+0
#    Installed StrideArraysCore ───────────────── v0.5.2
#    Installed RuntimeGeneratedFunctions ──────── v0.5.12
#    Installed GeometryBasics ─────────────────── v0.4.10
#    Installed ExponentialUtilities ───────────── v1.25.0
#    Installed Krylov ─────────────────────────── v0.9.5
#    Installed VectorizationBase ──────────────── v0.21.65
#    Installed VertexSafeGraphs ───────────────── v0.2.0
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed ShaderAbstractions ─────────────── v0.4.1
#    Installed TruncatedStacktraces ───────────── v1.4.0
#    Installed ConcreteStructs ────────────────── v0.2.3
#    Installed ResettableStacks ───────────────── v1.1.1
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed FastBroadcast ──────────────────── v0.2.8
#    Installed PoissonRandom ──────────────────── v0.4.4
#    Installed SymbolicIndexingInterface ──────── v0.3.5
#    Installed RecursiveFactorization ─────────── v0.2.21
#    Installed SparseDiffTools ────────────────── v2.16.0
#    Installed Sparspak ───────────────────────── v0.3.9
#    Installed DelaunayTriangulation ──────────── v0.8.12
#     Updating `C:\Users\hpark1\.julia\environments\v1.10\Project.toml`
#   [0c46a032] + DifferentialEquations v7.12.0
#     Updating `C:\Users\hpark1\.julia\environments\v1.10\Manifest.toml`
#   [47edcb42] + ADTypes v0.2.6
# ⌅ [79e6a3ab] ↓ Adapt v4.0.1 ⇒ v3.7.2
#   [ec485272] + ArnoldiMethod v0.2.0
#   [4c555306] + ArrayLayouts v1.6.0
#   [aae01518] + BandedMatrices v1.5.0
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
# ⌃ [764a87c0] + BoundaryValueDiffEq v5.6.0
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [96374032] - CRlibm v1.0.1
#   [d360d2e6] ↑ ChainRulesCore v1.19.1 ⇒ v1.20.1
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [944b1d66] ↑ CodecZlib v0.7.3 ⇒ v0.7.4
#   [38540f10] + CommonSolve v0.2.4
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [adafc99b] + CpuId v0.3.1
#   [927a84f5] ↑ DelaunayTriangulation v0.8.11 ⇒ v0.8.12
#   [bcd4f6db] + DelayDiffEq v5.46.0
#   [2b5f629d] + DiffEqBase v6.146.0
#   [459566f4] + DiffEqCallbacks v2.36.1
#   [77a26b50] + DiffEqNoiseProcess v5.20.0
#   [0c46a032] + DifferentialEquations v7.12.0
#   [b4f34e82] + Distances v0.10.11
#   [f151be2c] + EnzymeCore v0.6.5
#   [429591f6] ↑ ExactPredicates v2.2.7 ⇒ v2.2.8
#   [d4d017d3] + ExponentialUtilities v1.25.0
#   [e2ba6199] + ExprTools v0.1.10
#   [9d29842c] + FastAlmostBandedMatrices v0.1.0
#   [7034ab61] + FastBroadcast v0.2.8
#   [9aa1b823] + FastClosures v0.3.2
#   [29a986be] + FastLapackInterface v2.0.1
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [d9f16b24] + Functors v0.4.5
# ⌃ [46192b85] ↓ GPUArraysCore v0.1.6 ⇒ v0.1.5
#   [c145ed77] + GenericSchur v0.5.3
#   [5c1252a2] ↑ GeometryBasics v0.4.9 ⇒ v0.4.10
#   [86223c79] + Graphs v1.9.0
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [a09fc81d] ↑ ImageCore v0.10.1 ⇒ v0.10.2
#   [d1acc4aa] ↑ IntervalArithmetic v0.22.5 ⇒ v0.22.7
#   [ccbc3e58] + JumpProcesses v9.10.1
#   [ef3ab10e] + KLU v0.4.1
#   [ba0b0d4f] + Krylov v0.9.5
#   [10f19ff3] + LayoutPointers v0.1.15
#   [50d2b5c4] + Lazy v0.15.1
#   [5078a376] + LazyArrays v1.8.3
#   [2d8b4e74] + LevyArea v1.0.0
#   [7ed4a6bd] + LinearSolve v2.22.1
#   [bdcacae8] + LoopVectorization v0.12.166
#   [d125e4d3] + ManualMemory v0.1.8
#   [a3b82374] + MatrixFactorizations v2.1.0
#   [bb5d69b7] + MaybeInplace v0.1.1
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [2774e3e8] + NLsolve v4.5.1
#   [8913a72c] + NonlinearSolve v3.5.3
#   [1dea7af3] + OrdinaryDiffEq v6.70.1
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [e409e4f3] + PoissonRandom v0.4.4
#   [f517fe37] + Polyester v0.7.9
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [d236fae5] + PreallocationTools v0.4.17
#   [74087812] + Random123 v1.6.2
#   [e6cf234a] + RandomNumbers v1.5.3
#   [731186ca] + RecursiveArrayTools v3.8.0
#   [f2c3362d] + RecursiveFactorization v0.2.21
#   [ae5879a3] + ResettableStacks v1.1.1
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.12
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [0bca4576] + SciMLBase v2.23.1
#   [c0aeaf25] + SciMLOperators v0.3.7
#   [65257c39] ↑ ShaderAbstractions v0.4.0 ⇒ v0.4.1
#   [727e6d20] + SimpleNonlinearSolve v1.3.2
#   [ce78b400] + SimpleUnPack v1.1.0
#   [47a9eef4] + SparseDiffTools v2.16.0
#   [e56a9233] + Sparspak v0.3.9
#   [aedffcd0] + Static v0.8.9
#   [0d7ed370] + StaticArrayInterface v1.5.0
#   [90137ffa] ↑ StaticArrays v1.9.1 ⇒ v1.9.2
#   [9672c7b4] + SteadyStateDiffEq v2.0.1
#   [789caeaf] + StochasticDiffEq v6.64.0
#   [7792a7ef] + StrideArraysCore v0.5.2
#   [c3572dad] + Sundials v4.23.2
#   [2efcf032] + SymbolicIndexingInterface v0.3.5
#   [8290d209] + ThreadingUtilities v0.5.2
#   [a759f4b9] + TimerOutputs v0.5.23
#   [3bb67fe8] ↑ TranscodingStreams v0.10.2 ⇒ v0.10.3
#   [d5829a12] + TriangularSolve v0.1.20
#   [410a4b4d] + Tricks v0.1.8
#   [781d530d] + TruncatedStacktraces v1.4.0
#   [3d5dd08c] + VectorizationBase v0.21.65
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [458c3c95] ↑ OpenSSL_jll v3.0.12+0 ⇒ v3.0.13+0
# ⌅ [fb77eaff] + Sundials_jll v5.2.2+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Tricks
#   ✓ ConcreteStructs
#   ✓ ADTypes
#   ✓ SimpleUnPack
#   ✓ CpuId
#   ✓ FunctionWrappers
#   ✓ ChainRulesCore
#   ✓ CommonSolve
#   ✓ PackageExtensionCompat
#   ✓ PoissonRandom
#   ✓ ExprTools
#   ✓ ManualMemory
#   ✓ Functors
#   ✓ FastLapackInterface
#   ✓ IfElse
#   ✓ FastClosures
#   ✓ MuladdMacro
#   ✓ SIMDTypes
#   ✓ TranscodingStreams
#   ✓ EnzymeCore
#   ✓ Adapt
#   ✓ GenericSchur
#   ✓ SymbolicIndexingInterface
#   ✓ RandomNumbers
#   ✓ TruncatedStacktraces
#   ✓ OpenSSL_jll
#   ✓ KLU
#   ✓ Sundials_jll
#   ✓ Lazy
#   ✓ Distances
#   ✓ FunctionWrappersWrappers
#   ✓ RuntimeGeneratedFunctions
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ IntervalArithmetic
#   ✓ LevyArea
#   ✓ Static
#   ✓ ThreadingUtilities
#   ✓ EnzymeCore → AdaptExt
#   ✓ TimerOutputs
#   ✓ TranscodingStreams → TestExt
#   ✓ Sparspak
#   ✓ Krylov
#   ✓ Random123
#   ✓ Distances → DistancesSparseArraysExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ CodecZlib
#   ✓ StaticArrays
#   ? CPUSummary
#   ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ HostCPUFeatures
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ ArrayLayouts
#   ✓ IntervalArithmetic → IntervalArithmeticDiffRulesExt
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ GPUArraysCore
#   ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#   ✓ ResettableStacks
#   ✓ PolyesterWeave
#   ✓ ArnoldiMethod
#   ✓ MatrixFactorizations
#   ✓ HTTP
#   ✓ ExactPredicates
#   ✓ LazyArrays
#   ✓ LazyArrays → LazyArraysStaticArraysExt
#   ✓ Graphs
#   ✓ Bonito
#   ✓ CSV
#   ✓ VertexSafeGraphs
#   ✓ GeometryBasics
#   ✓ ImageCore
#   ✓ ShaderAbstractions
#   ✓ BandedMatrices
#   ✓ ImageBase
#   ✓ JpegTurbo
#   ✓ Sixel
#   ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   ✓ PNGFiles
#   ✓ ImageAxes
#   ✓ MaybeInplace
#   ✓ PreallocationTools
#   ✓ StaticArrayInterface
#   ✓ SciMLOperators
#   ✓ RecursiveArrayTools
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ ImageMetadata
#   ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ NLsolve
#   ✓ Netpbm
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ StrideArraysCore
#   ✓ DelaunayTriangulation
#   ✓ Polyester
#   ✓ FastAlmostBandedMatrices
#   ✓ FastBroadcast
#   ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   ✓ SparseDiffTools
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ SciMLBase
#   ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#   ✓ DiffEqBase
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ ExponentialUtilities
#   ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#   ✓ LoopVectorization
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ DiffEqCallbacks
#   ✓ JumpProcesses
#   ✓ TriangularSolve
#   ✓ DiffEqNoiseProcess
#   ✓ SteadyStateDiffEq
#   ✓ JumpProcesses → JumpProcessFastBroadcastExt
#   ✓ Sundials
#   ✓ RecursiveFactorization
#   ✓ SimpleNonlinearSolve
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveStaticArraysExt
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   ✓ LinearSolve
#   ✓ LinearSolve → LinearSolveFastAlmostBandedMatricesExt
#   ✓ LinearSolve → LinearSolveBandedMatricesExt
#   ✓ LinearSolve → LinearSolveRecursiveArrayToolsExt
#   ✓ NonlinearSolve
#   ✓ WGLMakie
#   ✓ NonlinearSolve → NonlinearSolveBandedMatricesExt
#   ✓ NonlinearSolve → NonlinearSolveNLsolveExt
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✓ BoundaryValueDiffEq
#   ✓ BoundaryValueDiffEq → BoundaryValueDiffEqOrdinaryDiffEqExt
#   ✓ DifferentialEquations
#   138 dependencies successfully precompiled in 1278 seconds. 318 already precompiled.
#   17 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency failed but may be precompilable after restarting julia
#   1 dependency had output during precompilation:
# ┌ CPUSummary
# │  WARNING: Method definition cache_size(Union{Base.Val{1}, Static.StaticInt{1}}) in module CPUSummary at C:\Users\hpark1\.julia\packages\CPUSummary\LAKF1\src\x86.jl:26 overwritten on the same line (check for duplicate calls to `include`).
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# Precompiling DifferentialEquations
#   ✓ CPUSummary
#   ✓ PolyesterWeave
#   ✓ Polyester
#   ✓ FastBroadcast
#   ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ DiffEqBase
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ DiffEqCallbacks
#   ✓ JumpProcesses
#   ✓ SteadyStateDiffEq
#   ✓ DiffEqNoiseProcess
#   ✓ JumpProcesses → JumpProcessFastBroadcastExt
#   ✓ Sundials
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ TriangularSolve
#   ✓ RecursiveFactorization
#   ✓ SimpleNonlinearSolve
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveStaticArraysExt
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   ✓ LinearSolve
#   ✓ LinearSolve → LinearSolveFastAlmostBandedMatricesExt
#   ✓ NonlinearSolve
#   ✓ NonlinearSolve → NonlinearSolveBandedMatricesExt
#   ✓ NonlinearSolve → NonlinearSolveNLsolveExt
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✓ BoundaryValueDiffEq
#   ✓ BoundaryValueDiffEq → BoundaryValueDiffEqOrdinaryDiffEqExt
#   ✓ DifferentialEquations
#   36 dependencies successfully precompiled in 1006 seconds. 167 already precompiled.
# [ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# [ Info: Precompiling IntervalArithmeticDiffRulesExt [86439bda-9ede-5c22-99a0-f82df582fb22]
# ┌ Warning: Module IntervalArithmetic with build ID fafbfcfd-8925-42a9-0000-53fb94ab9c25 is missing from the cache.
# │ This may mean IntervalArithmetic [d1acc4aa-44c8-5952-acd4-ba5d80a2a253] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1942
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticDiffRulesExt [86439bda-9ede-5c22-99a0-f82df582fb22].
# Precompiling SciMLBaseChainRulesCoreExt
#   ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#   1 dependency successfully precompiled in 28 seconds. 98 already precompiled.
# [ Info: Precompiling SciMLBaseChainRulesCoreExt [4676cac9-c8e0-5d6e-a4e0-e3351593cdf5]
# Precompiling DiffEqBaseChainRulesCoreExt
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#   2 dependencies successfully precompiled in 44 seconds. 109 already precompiled.
# [ Info: Precompiling DiffEqBaseChainRulesCoreExt [b00db79b-61e3-50fb-b26f-2d35b2d9e4ed]
# [ Info: Precompiling DistancesChainRulesCoreExt [ae626735-4632-5a5b-a2bf-d8e33c22a871]
# [ Info: Precompiling ForwardDiffExt [4b8ca102-9d0f-5df8-84ed-253e0f005ba7]
# Precompiling SimpleNonlinearSolveChainRulesCoreExt
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   1 dependency successfully precompiled in 85 seconds. 135 already precompiled.
# [ Info: Precompiling SimpleNonlinearSolveChainRulesCoreExt [073a8d7d-86ee-5d75-9348-f9bf6155b014]

# %%
# Set up by defining the discrete grid for Omega space
npoints = 51 # we first started with 5
h = 2 / (npoints - 1) # grid spacing (division is by 2 because ...)
# Out:
# 0.04

# %%
# It's convenient to put the whole state vector in a single vector!
U = zeros(npoints, npoints, 2) # will hold all field configurations at each point! (third argument is the third axis)

# More specifically, we define
function DifferentialEquations.init()
    # initial conditions
    x0 = 0.0
    y0 = -0.5
    W = 0.01
    
    U = zeros(npoints, npoints, 2)
    for j in 1:npoints, i in 1:npoints
        if i==1 || i==npoints || j==1 || j==npoints
            U[i,j,1]=0
            U[i,j,2]=0
        else
            x = -1 + (i-1)*h # at i=1, start from x = -1
            y = -1 + (j-1)*h # at j=1, start from y = -1
            phi = exp(-((x-x0)^2+(y-y0)^2)/2W)
            psi = 0
            U[i,j,1] = phi
            U[i,j,2] = psi
        end
    end
    return U
end

# %% [markdown]
# For finite differences, recall
# $$f_i''=\frac{f_{i-1}-2f_i+f_{i+1}}{h^2}.$$

# %%
# right hand side function
function rhs(U, p, t)
    # need p, t parameters to plug into ODE package's function!
    Udot = similar(U)

    for j in 1:npoints, i in 1:npoints
        if i==1 || i==npoints || j==1 || j==npoints
            Udot[i,j,1]=0
            Udot[i,j,2]=0
        else
            phixx = (U[i-1,j,1]-2*U[i,j,1]+U[i+1,j,1])/h^2 # recall U's third axis had phi stored in index 1!!
            phiyy = (U[i,j-1,1]-2*U[i,j,1]+U[i,j+1,1])/h^2
            Udot[i,j,1] = U[i,j,2]
            Udot[i,j,2] = phixx + phiyy
        end
    end
    return Udot
end

# For finite differeces, it's more customary to evaluate matrix at the point, rather than storing the value!
# Out:
# rhs (generic function with 1 method)

# %%
U0 = init()
tspan = (0.0, 4.0) # time span
prob = ODEProblem(rhs, U0, tspan)
sol = solve(prob);
length(sol.t)
# Out:
# 110

# %%
# Now let's plot
fig = Figure(size=(600, 600))
heatmap!([-1:h:+1, -1:h:-1], sol(0.0)[:,:,1];colorrange=(-1,1)) # init:stepsize:final
heatmap!([-1:h:+1, -1:h:-1], sol(3.0)[:,:,1];colorrange=(-1,1)) # init:stepsize:final
fig

# need to make sure aspect ratio is square! (which is NOT quite the figure size)
# Out:
# `Makie.convert_arguments` for the plot type Heatmap and its conversion trait CellGrid() was unsuccessful.
#
# The signature that could not be converted was:
# ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float32}
#
# Makie needs to convert all plot input arguments to types that can be consumed by the backends (typically Arrays with Float32 elements).
# You can define a method for `Makie.convert_arguments` (a type recipe) for these types or their supertypes to make this set of arguments convertible (See http://docs.makie.org/stable/documentation/recipes/index.html).
#
# Alternatively, you can define `Makie.convert_single_argument` for single arguments which have types that are unknown to Makie but which can be converted to known types and fed back to the conversion pipeline.
#
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] convert_arguments(::Type{Heatmap}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:17
#   [3] convert_arguments(::Type{Heatmap}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float32})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:7
#   [4] convert_arguments_individually(::Type{Heatmap}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:51
#   [5] convert_arguments(::Type{Heatmap}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:14
#   [6] convert_arguments(::Type{Heatmap}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float64})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:7
#   [7] (Heatmap)(args::Tuple{Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, Matrix{Float64}}, plot_attributes::Dict{Symbol, Any})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\interfaces.jl:139
#   [8] _create_plot!(::Function, ::Dict{Symbol, Any}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float64})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\figureplotting.jl:257
#   [9] heatmap!(::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{colorrange::Tuple{Int64, Int64}})
#     @ MakieCore C:\Users\hpark1\.julia\packages\MakieCore\5nuEY\src\recipes.jl:176
#  [10] top-level scope
#     @ In[31]:3

# %% [markdown]
# ^^^ Indeed, the function on the boundary is zero, at time 0, consistent with our chosen intial condition!

# %%
# Now let's plot
fig = Figure(size=(600, 600))
contourf!([-1:h:+1, -1:h:-1], sol(0.0)[:,:,1];colorrange=(-1,1)) # init:stepsize:final
contourf!([-1:h:+1, -1:h:-1], sol(3.0)[:,:,1];colorrange=(-1,1)) # init:stepsize:final
fig

# need to make sure aspect ratio is square!
# Out:
# `Makie.convert_arguments` for the plot type Plot{Makie.contourf} and its conversion trait VertexGrid() was unsuccessful.
#
# The signature that could not be converted was:
# ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float32}
#
# Makie needs to convert all plot input arguments to types that can be consumed by the backends (typically Arrays with Float32 elements).
# You can define a method for `Makie.convert_arguments` (a type recipe) for these types or their supertypes to make this set of arguments convertible (See http://docs.makie.org/stable/documentation/recipes/index.html).
#
# Alternatively, you can define `Makie.convert_single_argument` for single arguments which have types that are unknown to Makie but which can be converted to known types and fed back to the conversion pipeline.
#
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] convert_arguments(::Type{Plot{Makie.contourf}}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:17
#   [3] convert_arguments(::Type{Plot{Makie.contourf}}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float32})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:7
#   [4] convert_arguments_individually(::Type{Plot{Makie.contourf}}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:51
#   [5] convert_arguments(::Type{Plot{Makie.contourf}}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:14
#   [6] convert_arguments(::Type{Plot{Makie.contourf}}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float64})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\conversions.jl:7
#   [7] (Plot{Makie.contourf})(args::Tuple{Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, Matrix{Float64}}, plot_attributes::Dict{Symbol, Any})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\interfaces.jl:139
#   [8] _create_plot!(::Function, ::Dict{Symbol, Any}, ::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Matrix{Float64})
#     @ Makie C:\Users\hpark1\.julia\packages\Makie\fyNiH\src\figureplotting.jl:257
#   [9] contourf!(::Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}, ::Vararg{Any}; kw::@Kwargs{colorrange::Tuple{Int64, Int64}})
#     @ Makie C:\Users\hpark1\.julia\packages\MakieCore\5nuEY\src\recipes.jl:176
#  [10] top-level scope
#     @ In[32]:3

# %%
# Now let's plot
fig = Figure(size=(640, 400))
axis = Axis(fig[1,1])
lines!(axis, -1:h:+1, sol(0.0)[:,(npoints+1)+2,1]) # init:stepsize:final
lines!(axis, -1:h:+1, sol(0.5)[:,(npoints+1)+2,1]) # init:stepsize:final
lines!(axis, -1:h:+1, sol(1.0)[:,(npoints+1)+2,1]) # init:stepsize:final
lines!(axis, -1:h:+1, sol(1.5)[:,(npoints+1)+2,1]) # init:stepsize:final
lines!(axis, -1:h:+1, sol(2.0)[:,(npoints+1)+2,1]) # init:stepsize:final
fig
# Out:
# BoundsError: attempt to access 51×51×2 Array{Float64, 3} at index [1:51, 54, 1]
#
# Stacktrace:
#  [1] throw_boundserror(A::Array{Float64, 3}, I::Tuple{Base.Slice{Base.OneTo{Int64}}, Int64, Int64})
#    @ Base .\abstractarray.jl:734
#  [2] checkbounds
#    @ Base .\abstractarray.jl:699 [inlined]
#  [3] _getindex
#    @ Base .\multidimensional.jl:888 [inlined]
#  [4] getindex(::Array{Float64, 3}, ::Function, ::Int64, ::Int64)
#    @ Base .\abstractarray.jl:1288
#  [5] top-level scope
#    @ In[33]:4

# %% [markdown]
# ## Effect of Resolution
# twice the resolution, 8 times the operation time!

# %%
# It's convenient to put the whole state vector in a single vector!
U = zeros(npoints, npoints, 2) # will hold all field configurations at each point! (third argument is the third axis)

# More specifically, we define
function init(npoints)
    h = 2/(npoints-1)
    # initial conditions
    x0 = 0.0
    y0 = -0.5
    W = 0.01
    
    U = zeros(npoints, npoints, 2)
    for j in 1:npoints, i in 1:npoints
        if i==1 || i==npoints || j==1 || j=npoints
            U[i,j,1]=0
            U[i,j,2]=0
        else
            x = -1 + (i-1)*h # at i=1, start from x = -1
            y = -1 + (j-1)*h # at j=1, start from y = -1
            phi = exp(-((x-x0)^2+(y-y0)^2)/2W)
            psi = 0
            U[i,j,1] = phi
            U[i,j,2] = psi
        end
    end
    return U
end

# %%
# right hand side function
function rhs(U, p, t)
    npoints = length(U)
    # need p, t parameters to plug into ODE package's function!
    Udot = similar(U)

    for j in 1:npoints, i in 1:npoints
        if i==1 || i==npoints || j==1 || j=npoints
            Udot[i,j,1]=0
            Udot[i,j,2]=0
        else
            phixx = (U[i-1,j,1]-2*U[i,j,1]+U[i+1,j,1])/h^2 # recall U's third axis had phi stored in index 1!!
            phiyy = (U[i,j-1,1]-2*U[i,j,1]+U[i,j+1,1])/h^2
            Udot[i,j,1] = U[i,j,2]
            Udot[i,j,2] = phixx + phiyy
        end
    end
    return Udot
end

# For finite differeces, it's more customary to evaluate matrix at the point, rather than storing the value!

# %% [markdown]
# ...julia: `end` command in square bracket looks at the last index point!

# %% [markdown]
# ## Convergence

# %% [markdown]
# $$\left(\int_\Omega|f_n(t,x)-f^*(t,x)|^2 dx\right)^2 = O(h^2)$$
#
# In logE vs logh plot, we'll see a plot with trend: ---\ \ \ \ \ \ \------10^-15 (floating point error---computer's minimum error)!
#
# Finite differencing method has larger error than 10^-15
